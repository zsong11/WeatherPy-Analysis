# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
from citipy import citipy

# %%
output_file = "output_data/cities.csv"

# %%
lat_lngs = []
cities = []

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 644

# %%
api_key = "9f4c01a28b18cad571374f6bddc54116"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

city_data = []

print("Data Retrieval Begin")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
        
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    city_url = url + "&q=" + city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city} ")

    record_count += 1

    try:
        city_weather = requests.get(city_url).json()

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    except:
        print("City not found. Skipping...")
        pass
              
print("Data Retrieval Complete")
# Out:
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | rafaela
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 1 | coquimbo
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | manggar
# Processing Record 14 of Set 1 | atikokan
# Processing Record 15 of Set 1 | marsh harbour
# Processing Record 16 of Set 1 | touros
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | antalaha
# Processing Record 19 of Set 1 | airai
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | nemuro
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | dayong
# Processing Record 27 of Set 1 | thinadhoo
# Processing Record 28 of Set 1 | okha
# Processing Record 29 of Set 1 | kijabe
# Processing Record 30 of Set 1 | muisne
# Processing Record 31 of Set 1 | nampa
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | cananeia
# Processing Record 37 of Set 1 | yekaterinoslavka
# Processing Record 38 of Set 1 | henties bay
# Processing Record 39 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | necochea
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | cabinda
# Processing Record 45 of Set 1 | ulladulla
# Processing Record 46 of Set 1 | weihe
# Processing Record 47 of Set 1 | srednekolymsk
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | roald
# Processing Record 50 of Set 1 | luderitz
# Processing Record 0 of Set 2 | koster
# Processing Record 1 of Set 2 | chiredzi
# Processing Record 2 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 3 of Set 2 | capaccio
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | port augusta
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | wanxian
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | constantine
# Processing Record 16 of Set 2 | liwale
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | grand baie
# Processing Record 21 of Set 2 | meulaboh
# Processing Record 22 of Set 2 | waltershausen
# Processing Record 23 of Set 2 | shizunai
# Processing Record 24 of Set 2 | imeni poliny osipenko
# Processing Record 25 of Set 2 | praia da vitoria
# Processing Record 26 of Set 2 | reefton
# City not found. Skipping...
# Processing Record 27 of Set 2 | dondo
# Processing Record 28 of Set 2 | esperance
# Processing Record 29 of Set 2 | solwezi
# Processing Record 30 of Set 2 | caala
# Processing Record 31 of Set 2 | ancud
# Processing Record 32 of Set 2 | boguchany
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | bathsheba
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | mandan
# Processing Record 40 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | belyy yar
# Processing Record 43 of Set 2 | gao
# Processing Record 44 of Set 2 | porkhov
# Processing Record 45 of Set 2 | singojuruh
# Processing Record 46 of Set 2 | hamilton
# Processing Record 47 of Set 2 | hailun
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | adrar
# Processing Record 0 of Set 3 | yeehaw junction
# City not found. Skipping...
# Processing Record 1 of Set 3 | lasa
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | kang
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | pasni
# Processing Record 6 of Set 3 | tambul
# City not found. Skipping...
# Processing Record 7 of Set 3 | adre
# Processing Record 8 of Set 3 | vezirkopru
# Processing Record 9 of Set 3 | poronaysk
# Processing Record 10 of Set 3 | arraial do cabo
# Processing Record 11 of Set 3 | san luis
# Processing Record 12 of Set 3 | gediz
# Processing Record 13 of Set 3 | muyezerskiy
# Processing Record 14 of Set 3 | laguna
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | vestmannaeyjar
# Processing Record 17 of Set 3 | tucuman
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | fort nelson
# Processing Record 21 of Set 3 | atuona
# Processing Record 22 of Set 3 | santa maria da vitoria
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | karratha
# Processing Record 25 of Set 3 | carballo
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | llanes
# Processing Record 28 of Set 3 | tena
# Processing Record 29 of Set 3 | uchkeken
# Processing Record 30 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 3 | mount gambier
# Processing Record 32 of Set 3 | margate
# Processing Record 33 of Set 3 | nyurba
# Processing Record 34 of Set 3 | oron
# Processing Record 35 of Set 3 | burnie
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | yerbogachen
# Processing Record 38 of Set 3 | portland
# Processing Record 39 of Set 3 | malumfashi
# Processing Record 40 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 41 of Set 3 | turiacu
# Processing Record 42 of Set 3 | bajo baudo
# City not found. Skipping...
# Processing Record 43 of Set 3 | la plata
# Processing Record 44 of Set 3 | bud
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | noumea
# Processing Record 47 of Set 3 | port hedland
# Processing Record 48 of Set 3 | kavaratti
# Processing Record 49 of Set 3 | port alfred
# Processing Record 0 of Set 4 | victoria
# Processing Record 1 of Set 4 | shaunavon
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | hualmay
# Processing Record 4 of Set 4 | ostrovnoy
# Processing Record 5 of Set 4 | kondinskoye
# Processing Record 6 of Set 4 | cache creek
# Processing Record 7 of Set 4 | senanga
# Processing Record 8 of Set 4 | vila franca do campo
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | ternate
# Processing Record 11 of Set 4 | rabo de peixe
# Processing Record 12 of Set 4 | london
# Processing Record 13 of Set 4 | hirara
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | hobart
# Processing Record 16 of Set 4 | amazar
# Processing Record 17 of Set 4 | zelenoborsk
# Processing Record 18 of Set 4 | alexandria
# Processing Record 19 of Set 4 | half moon bay
# Processing Record 20 of Set 4 | kibaya
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | baykit
# Processing Record 23 of Set 4 | richards bay
# Processing Record 24 of Set 4 | igarka
# Processing Record 25 of Set 4 | beringovskiy
# Processing Record 26 of Set 4 | lazaro cardenas
# Processing Record 27 of Set 4 | manzanillo
# Processing Record 28 of Set 4 | bubaque
# Processing Record 29 of Set 4 | pacific grove
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | taksimo
# Processing Record 32 of Set 4 | san andres
# Processing Record 33 of Set 4 | broken hill
# Processing Record 34 of Set 4 | sioux lookout
# Processing Record 35 of Set 4 | mocuba
# Processing Record 36 of Set 4 | dokka
# Processing Record 37 of Set 4 | pangoa
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | chokurdakh
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 4 | te anau
# Processing Record 43 of Set 4 | padang
# Processing Record 44 of Set 4 | isangel
# Processing Record 45 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 4 | baiyin
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | lompoc
# Processing Record 49 of Set 4 | omsukchan
# Processing Record 0 of Set 5 | doka
# Processing Record 1 of Set 5 | buala
# Processing Record 2 of Set 5 | awjilah
# Processing Record 3 of Set 5 | thayetmyo
# Processing Record 4 of Set 5 | saint-pierre
# Processing Record 5 of Set 5 | la ronge
# Processing Record 6 of Set 5 | el wasta
# City not found. Skipping...
# Processing Record 7 of Set 5 | monte alegre
# Processing Record 8 of Set 5 | black river
# Processing Record 9 of Set 5 | georgetown
# Processing Record 10 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 11 of Set 5 | palmer
# Processing Record 12 of Set 5 | lagoa
# Processing Record 13 of Set 5 | maksatikha
# Processing Record 14 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 5 | ranong
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 5 | lima
# Processing Record 19 of Set 5 | morondava
# Processing Record 20 of Set 5 | odder
# Processing Record 21 of Set 5 | scarborough
# Processing Record 22 of Set 5 | sambava
# Processing Record 23 of Set 5 | pangnirtung
# Processing Record 24 of Set 5 | svetlaya
# Processing Record 25 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | santa isabel do rio negro
# Processing Record 28 of Set 5 | new philadelphia
# Processing Record 29 of Set 5 | christchurch
# Processing Record 30 of Set 5 | kodiak
# Processing Record 31 of Set 5 | minsk
# Processing Record 32 of Set 5 | la rioja
# Processing Record 33 of Set 5 | xining
# Processing Record 34 of Set 5 | mayo
# Processing Record 35 of Set 5 | namibe
# Processing Record 36 of Set 5 | waingapu
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 5 | walla walla
# Processing Record 40 of Set 5 | camrose
# Processing Record 41 of Set 5 | dickinson
# Processing Record 42 of Set 5 | whitehorse
# Processing Record 43 of Set 5 | ilo
# Processing Record 44 of Set 5 | kloulklubed
# Processing Record 45 of Set 5 | upington
# Processing Record 46 of Set 5 | la orilla
# Processing Record 47 of Set 5 | simao
# Processing Record 48 of Set 5 | mar del plata
# Processing Record 49 of Set 5 | byron bay
# Processing Record 0 of Set 6 | egvekinot
# Processing Record 1 of Set 6 | mayaky
# Processing Record 2 of Set 6 | pucallpa
# Processing Record 3 of Set 6 | cayhagan
# Processing Record 4 of Set 6 | poum
# Processing Record 5 of Set 6 | la sarre
# Processing Record 6 of Set 6 | campo verde
# Processing Record 7 of Set 6 | aktau
# Processing Record 8 of Set 6 | komsomolskiy
# Processing Record 9 of Set 6 | cururupu
# Processing Record 10 of Set 6 | qianan
# Processing Record 11 of Set 6 | storforshei
# Processing Record 12 of Set 6 | belaya gora
# Processing Record 13 of Set 6 | xiongzhou
# Processing Record 14 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 6 | victor harbor
# Processing Record 16 of Set 6 | starychi
# Processing Record 17 of Set 6 | boca do acre
# Processing Record 18 of Set 6 | acarau
# City not found. Skipping...
# Processing Record 19 of Set 6 | ginir
# Processing Record 20 of Set 6 | cuautepec
# Processing Record 21 of Set 6 | ibadan
# Processing Record 22 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 6 | khurba
# Processing Record 24 of Set 6 | gorontalo
# Processing Record 25 of Set 6 | tabas
# Processing Record 26 of Set 6 | salalah
# Processing Record 27 of Set 6 | araguaina
# Processing Record 28 of Set 6 | ca mau
# Processing Record 29 of Set 6 | palasa
# City not found. Skipping...
# Processing Record 30 of Set 6 | takoradi
# Processing Record 31 of Set 6 | lebu
# Processing Record 32 of Set 6 | khatanga
# Processing Record 33 of Set 6 | tual
# Processing Record 34 of Set 6 | rawlins
# Processing Record 35 of Set 6 | kaohsiung
# Processing Record 36 of Set 6 | chara
# Processing Record 37 of Set 6 | beira
# Processing Record 38 of Set 6 | quatre cocos
# Processing Record 39 of Set 6 | bay roberts
# Processing Record 40 of Set 6 | genhe
# Processing Record 41 of Set 6 | susanville
# Processing Record 42 of Set 6 | general pico
# Processing Record 43 of Set 6 | venice
# Processing Record 44 of Set 6 | kingston
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | poyarkovo
# Processing Record 47 of Set 6 | sanming
# Processing Record 48 of Set 6 | huruta
# Processing Record 49 of Set 6 | vanimo
# Processing Record 0 of Set 7 | fairbanks
# Processing Record 1 of Set 7 | faya
# Processing Record 2 of Set 7 | champerico
# Processing Record 3 of Set 7 | tasiilaq
# Processing Record 4 of Set 7 | atasu
# Processing Record 5 of Set 7 | burica
# City not found. Skipping...
# Processing Record 6 of Set 7 | kapit
# Processing Record 7 of Set 7 | vestmanna
# Processing Record 8 of Set 7 | dharchula
# Processing Record 9 of Set 7 | luhyny
# Processing Record 10 of Set 7 | ahipara
# Processing Record 11 of Set 7 | sabang
# Processing Record 12 of Set 7 | rio cuarto
# Processing Record 13 of Set 7 | salinopolis
# Processing Record 14 of Set 7 | springbok
# Processing Record 15 of Set 7 | hobyo
# Processing Record 16 of Set 7 | ribeira grande
# Processing Record 17 of Set 7 | rognan
# Processing Record 18 of Set 7 | nelson bay
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | opuwo
# Processing Record 21 of Set 7 | vung tau
# Processing Record 22 of Set 7 | tautira
# Processing Record 23 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 7 | kalmunai
# Processing Record 25 of Set 7 | mahebourg
# Processing Record 26 of Set 7 | azare
# Processing Record 27 of Set 7 | sinnamary
# Processing Record 28 of Set 7 | dimona
# Processing Record 29 of Set 7 | gannan
# Processing Record 30 of Set 7 | dolores
# Processing Record 31 of Set 7 | nouakchott
# Processing Record 32 of Set 7 | buraydah
# Processing Record 33 of Set 7 | begowal
# Processing Record 34 of Set 7 | ytre arna
# Processing Record 35 of Set 7 | glasgow
# Processing Record 36 of Set 7 | gat
# Processing Record 37 of Set 7 | viljoenskroon
# Processing Record 38 of Set 7 | manado
# Processing Record 39 of Set 7 | port macquarie
# Processing Record 40 of Set 7 | tanta
# Processing Record 41 of Set 7 | cortez
# Processing Record 42 of Set 7 | dedougou
# Processing Record 43 of Set 7 | wadi maliz
# Processing Record 44 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 46 of Set 7 | todos santos
# Processing Record 47 of Set 7 | linguere
# City not found. Skipping...
# Processing Record 48 of Set 7 | nikolskoye
# Processing Record 49 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 0 of Set 8 | tessalit
# Processing Record 1 of Set 8 | kaitangata
# Processing Record 2 of Set 8 | bairiki
# City not found. Skipping...
# Processing Record 3 of Set 8 | anshun
# Processing Record 4 of Set 8 | puro
# Processing Record 5 of Set 8 | vostok
# Processing Record 6 of Set 8 | bambous virieux
# Processing Record 7 of Set 8 | rozhyshche
# Processing Record 8 of Set 8 | briceno
# Processing Record 9 of Set 8 | aranos
# Processing Record 10 of Set 8 | salinas
# Processing Record 11 of Set 8 | brae
# Processing Record 12 of Set 8 | caravelas
# Processing Record 13 of Set 8 | fushun
# Processing Record 14 of Set 8 | pingliang
# Processing Record 15 of Set 8 | bend
# Processing Record 16 of Set 8 | orange
# Processing Record 17 of Set 8 | dukat
# Processing Record 18 of Set 8 | cidreira
# Processing Record 19 of Set 8 | wa
# City not found. Skipping...
# Processing Record 20 of Set 8 | nesterov
# Processing Record 21 of Set 8 | radhanpur
# Processing Record 22 of Set 8 | lesnoy
# Processing Record 23 of Set 8 | alamosa
# Processing Record 24 of Set 8 | chegdomyn
# Processing Record 25 of Set 8 | orda
# Processing Record 26 of Set 8 | abashiri
# Processing Record 27 of Set 8 | maxixe
# Processing Record 28 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 29 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 30 of Set 8 | tarut
# Processing Record 31 of Set 8 | havre-saint-pierre
# Processing Record 32 of Set 8 | svetlogorsk
# Processing Record 33 of Set 8 | musoma
# Processing Record 34 of Set 8 | vinh long
# Processing Record 35 of Set 8 | saldanha
# Processing Record 36 of Set 8 | pochutla
# Processing Record 37 of Set 8 | maarianhamina
# City not found. Skipping...
# Processing Record 38 of Set 8 | bhag
# Processing Record 39 of Set 8 | biltine
# Processing Record 40 of Set 8 | kruisfontein
# Processing Record 41 of Set 8 | moerai
# Processing Record 42 of Set 8 | pilot butte
# Processing Record 43 of Set 8 | cozumel
# City not found. Skipping...
# Processing Record 44 of Set 8 | konce
# Processing Record 45 of Set 8 | strezhevoy
# Processing Record 46 of Set 8 | narsaq
# Processing Record 47 of Set 8 | pecos
# Processing Record 48 of Set 8 | santa marta
# Processing Record 49 of Set 8 | zhigansk
# Processing Record 0 of Set 9 | tiksi
# Processing Record 1 of Set 9 | nador
# Processing Record 2 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 9 | havoysund
# Processing Record 6 of Set 9 | nazarovo
# Processing Record 7 of Set 9 | bezhanitsy
# Processing Record 8 of Set 9 | roela
# Processing Record 9 of Set 9 | kibala
# Processing Record 10 of Set 9 | zaraza
# Processing Record 11 of Set 9 | lexington
# Processing Record 12 of Set 9 | axim
# Processing Record 13 of Set 9 | itoman
# Processing Record 14 of Set 9 | mitu
# Processing Record 15 of Set 9 | kamphaeng phet
# Processing Record 16 of Set 9 | priargunsk
# Processing Record 17 of Set 9 | celestun
# Processing Record 18 of Set 9 | shkotovo-26
# City not found. Skipping...
# Processing Record 19 of Set 9 | alta floresta
# Processing Record 20 of Set 9 | pizarro
# Processing Record 21 of Set 9 | hajiganj
# Processing Record 22 of Set 9 | barbastro
# Processing Record 23 of Set 9 | riyadh
# Processing Record 24 of Set 9 | fonte boa
# Processing Record 25 of Set 9 | jumla
# Processing Record 26 of Set 9 | tateyama
# Processing Record 27 of Set 9 | ishigaki
# Processing Record 28 of Set 9 | saint anthony
# Processing Record 29 of Set 9 | coihaique
# Processing Record 30 of Set 9 | ambon
# Processing Record 31 of Set 9 | balabac
# Processing Record 32 of Set 9 | papara
# Processing Record 33 of Set 9 | hofn
# Processing Record 34 of Set 9 | kampene
# Processing Record 35 of Set 9 | harper
# Processing Record 36 of Set 9 | sotouboua
# Processing Record 37 of Set 9 | zhezkazgan
# Processing Record 38 of Set 9 | vra
# Processing Record 39 of Set 9 | westport
# Processing Record 40 of Set 9 | bowen
# Processing Record 41 of Set 9 | ngunguru
# Processing Record 42 of Set 9 | biryusinsk
# Processing Record 43 of Set 9 | sao filipe
# Processing Record 44 of Set 9 | caibarien
# Processing Record 45 of Set 9 | tahta
# City not found. Skipping...
# Processing Record 46 of Set 9 | tolaga bay
# Processing Record 47 of Set 9 | dunn
# Processing Record 48 of Set 9 | mae hong son
# Processing Record 49 of Set 9 | port arthur
# Processing Record 0 of Set 10 | bireun
# Processing Record 1 of Set 10 | salta
# Processing Record 2 of Set 10 | leh
# Processing Record 3 of Set 10 | bac lieu
# City not found. Skipping...
# Processing Record 4 of Set 10 | ico
# Processing Record 5 of Set 10 | zhitikara
# City not found. Skipping...
# Processing Record 6 of Set 10 | mandalgovi
# Processing Record 7 of Set 10 | seoul
# Processing Record 8 of Set 10 | los llanos de aridane
# Processing Record 9 of Set 10 | shenjiamen
# Processing Record 10 of Set 10 | bambanglipuro
# Processing Record 11 of Set 10 | clyde river
# Processing Record 12 of Set 10 | bereznik
# Processing Record 13 of Set 10 | northam
# Processing Record 14 of Set 10 | camacha
# Processing Record 15 of Set 10 | otavi
# Processing Record 16 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 10 | north myrtle beach
# Processing Record 18 of Set 10 | souillac
# Processing Record 19 of Set 10 | erenhot
# Processing Record 20 of Set 10 | san quintin
# Processing Record 21 of Set 10 | bandundu
# Processing Record 22 of Set 10 | soyo
# Processing Record 23 of Set 10 | longhua
# Processing Record 24 of Set 10 | seddon
# Processing Record 25 of Set 10 | talara
# Processing Record 26 of Set 10 | kahului
# Processing Record 27 of Set 10 | yokosuka
# Processing Record 28 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 10 | sidi ali
# Processing Record 30 of Set 10 | kirakira
# Processing Record 31 of Set 10 | mareeba
# Processing Record 32 of Set 10 | kalakamati
# Processing Record 33 of Set 10 | asau
# City not found. Skipping...
# Processing Record 34 of Set 10 | udachnyy
# Processing Record 35 of Set 10 | innisfail
# Processing Record 36 of Set 10 | luanda
# Processing Record 37 of Set 10 | jackson
# Processing Record 38 of Set 10 | onguday
# Processing Record 39 of Set 10 | skjervoy
# Processing Record 40 of Set 10 | alofi
# Processing Record 41 of Set 10 | vilyuysk
# Processing Record 42 of Set 10 | krasnoshchekovo
# Processing Record 43 of Set 10 | ipixuna
# Processing Record 44 of Set 10 | mahajanga
# Processing Record 45 of Set 10 | husavik
# Processing Record 46 of Set 10 | xingyi
# Processing Record 47 of Set 10 | balaipungut
# Processing Record 48 of Set 10 | tukrah
# City not found. Skipping...
# Processing Record 49 of Set 10 | eirunepe
# Processing Record 0 of Set 11 | san roque
# Processing Record 1 of Set 11 | salym
# Processing Record 2 of Set 11 | le locle
# Processing Record 3 of Set 11 | kisiwani
# Processing Record 4 of Set 11 | umm lajj
# Processing Record 5 of Set 11 | sao sebastiao
# Processing Record 6 of Set 11 | porterville
# Processing Record 7 of Set 11 | jiaohe
# Processing Record 8 of Set 11 | noyabrsk
# Processing Record 9 of Set 11 | jalingo
# Processing Record 10 of Set 11 | sorong
# Processing Record 11 of Set 11 | sassandra
# Processing Record 12 of Set 11 | ballina
# Processing Record 13 of Set 11 | senno
# Processing Record 14 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 11 | tura
# Processing Record 16 of Set 11 | bagaha
# Processing Record 17 of Set 11 | churapcha
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | ati
# Processing Record 20 of Set 11 | iaciara
# Processing Record 21 of Set 11 | andenes
# City not found. Skipping...
# Processing Record 22 of Set 11 | klaksvik
# Processing Record 23 of Set 11 | rocky mountain house
# Processing Record 24 of Set 11 | nago
# Processing Record 25 of Set 11 | zwedru
# Processing Record 26 of Set 11 | tripoli
# Processing Record 27 of Set 11 | rostock
# Processing Record 28 of Set 11 | la crosse
# Processing Record 29 of Set 11 | tolga
# Processing Record 30 of Set 11 | fortuna
# Processing Record 31 of Set 11 | bonoua
# Processing Record 32 of Set 11 | porto recanati
# Processing Record 33 of Set 11 | san patricio
# Processing Record 34 of Set 11 | frontera
# Processing Record 35 of Set 11 | la serena
# Processing Record 36 of Set 11 | quzhou
# Processing Record 37 of Set 11 | jiangyou
# Processing Record 38 of Set 11 | maningrida
# Processing Record 39 of Set 11 | miraflores
# Processing Record 40 of Set 11 | darab
# Processing Record 41 of Set 11 | comodoro rivadavia
# Processing Record 42 of Set 11 | cabedelo
# Processing Record 43 of Set 11 | korem
# Processing Record 44 of Set 11 | trinidad
# Processing Record 45 of Set 11 | porto novo
# Processing Record 46 of Set 11 | paso del toro
# Processing Record 47 of Set 11 | natal
# Processing Record 48 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 49 of Set 11 | yar-sale
# Processing Record 0 of Set 12 | banamba
# Processing Record 1 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 12 | tongren
# Processing Record 3 of Set 12 | sao raimundo das mangabeiras
# Processing Record 4 of Set 12 | tazovskiy
# Processing Record 5 of Set 12 | zhuhai
# Processing Record 6 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 12 | angoche
# Processing Record 8 of Set 12 | tucurui
# Processing Record 9 of Set 12 | bikin
# Processing Record 10 of Set 12 | liverpool
# Processing Record 11 of Set 12 | lausen
# Processing Record 12 of Set 12 | el alto
# Processing Record 13 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 12 | catuday
# Processing Record 15 of Set 12 | nieuw amsterdam
# Processing Record 16 of Set 12 | plettenberg bay
# Processing Record 17 of Set 12 | muzhi
# Processing Record 18 of Set 12 | casablanca
# Processing Record 19 of Set 12 | kindu
# Processing Record 20 of Set 12 | maniwaki
# Processing Record 21 of Set 12 | lata
# Processing Record 22 of Set 12 | laramie
# Processing Record 23 of Set 12 | kefalos
# Processing Record 24 of Set 12 | gambela
# Processing Record 25 of Set 12 | mogadishu
# Processing Record 26 of Set 12 | leningradskiy
# Processing Record 27 of Set 12 | freetown
# Processing Record 28 of Set 12 | schweinfurt
# Processing Record 29 of Set 12 | altay
# Processing Record 30 of Set 12 | saryg-sep
# Processing Record 31 of Set 12 | owensboro
# Processing Record 32 of Set 12 | atambua
# Processing Record 33 of Set 12 | yumen
# Processing Record 34 of Set 12 | kosikha
# Processing Record 35 of Set 12 | russell
# Processing Record 36 of Set 12 | tecoanapa
# Processing Record 37 of Set 12 | ketchikan
# Processing Record 38 of Set 12 | high point
# Processing Record 39 of Set 12 | guaruja
# Processing Record 40 of Set 12 | kieta
# Processing Record 41 of Set 12 | constitucion
# Processing Record 42 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 43 of Set 12 | oranjestad
# Processing Record 44 of Set 12 | kayalpattinam
# Processing Record 45 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 12 | khromtau
# Processing Record 47 of Set 12 | grand gaube
# Processing Record 48 of Set 12 | syracuse
# Processing Record 49 of Set 12 | batticaloa
# Processing Record 0 of Set 13 | cayenne
# Processing Record 1 of Set 13 | arlit
# Processing Record 2 of Set 13 | roma
# Processing Record 3 of Set 13 | ahar
# Processing Record 4 of Set 13 | gornozavodsk
# Processing Record 5 of Set 13 | betare oya
# Processing Record 6 of Set 13 | aykhal
# Processing Record 7 of Set 13 | evensk
# Processing Record 8 of Set 13 | nokaneng
# Processing Record 9 of Set 13 | dalvik
# Processing Record 10 of Set 13 | gonbad-e qabus
# Processing Record 11 of Set 13 | aklavik
# Processing Record 12 of Set 13 | patancheru
# Processing Record 13 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 14 of Set 13 | oksfjord
# Processing Record 15 of Set 13 | mehamn
# Processing Record 16 of Set 13 | anantapur
# Processing Record 17 of Set 13 | san juan
# Processing Record 18 of Set 13 | tyukhtet
# Processing Record 19 of Set 13 | suure-jaani
# Processing Record 20 of Set 13 | usogorsk
# Processing Record 21 of Set 13 | hambantota
# Processing Record 22 of Set 13 | bose
# Processing Record 23 of Set 13 | rairangpur
# Processing Record 24 of Set 13 | porto santo
# City not found. Skipping...
# Processing Record 25 of Set 13 | boa vista
# Processing Record 26 of Set 13 | cherskiy
# Processing Record 27 of Set 13 | dingle
# Processing Record 28 of Set 13 | bandar
# Processing Record 29 of Set 13 | riberalta
# Processing Record 30 of Set 13 | chapais
# Processing Record 31 of Set 13 | asmara
# Processing Record 32 of Set 13 | sterling
# Processing Record 33 of Set 13 | pavagada
# Processing Record 34 of Set 13 | himora
# City not found. Skipping...
# Processing Record 35 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 13 | mayna
# Processing Record 37 of Set 13 | lovington
# Processing Record 38 of Set 13 | tignere
# Processing Record 39 of Set 13 | orlik
# Processing Record 40 of Set 13 | khandbari
# Processing Record 41 of Set 13 | bosaso
# Processing Record 42 of Set 13 | taltal
# Processing Record 43 of Set 13 | grindavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  yellowknife          90      CA  1548900000        76  62.45 -114.38
# 1      rafaela          68      AR  1548903030        91 -31.25  -61.49
# 2       faanui          88      PF  1548903387        99 -16.48 -151.75
# 3     coquimbo          75      CL  1548900000        93 -29.95  -71.34
# 4      mataura          44      NZ  1548903252        41 -46.19  168.86
# 5  provideniya          75      RU  1548901800        57  64.42 -173.23
# 6        pevek          44      RU  1548903249        93  69.70  170.27
# 7       barrow           0      AR  1548903277        86 -38.31  -60.23
# 8     thompson           5      CA  1548900000        65  55.74  -97.86
# 9    jamestown           0      AU  1548903093        44 -33.21  138.60
#
#    Max Temp  Wind Speed
# 0     -5.81        6.93
# 1     79.48        2.95
# 2     83.98       20.07
# 3     62.60        5.82
# 4     85.69       20.07
# 5     19.40       20.13
# 6    -21.15        3.85
# 7     58.51        6.20
# 8    -36.41        2.62
# 9     76.91       11.01

# %%
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# %%
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_pd.count()
# Out:
# City          581
# Cloudiness    581
# Country       581
# Date          581
# Humidity      581
# Lat           581
# Lng           581
# Max Temp      581
# Wind Speed    581
# dtype: int64

# %%
#Latitude vs Temperature

plt.scatter(lats, max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("Latitude vs Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig1.png")
plt.show()

# %%
#Latitude vs Humidity
plt.scatter(lats, humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("Latitude vs Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig2.png")
plt.show()

# %%
#Latitude vs Cloudiness
plt.scatter(lats, cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("Latitude vs Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig3.png")
plt.show()

# %%
#Latitude vs Wind Speed
plt.scatter(lats, wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("Latitude vs Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig4.png")
plt.show()
